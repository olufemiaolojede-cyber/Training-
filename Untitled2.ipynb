# %%
import numpy as np

# %%
print(np)
# Out:
# <module 'numpy' from 'C:\\Users\\foloj\\anaconda3\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
num = [[ 1,2]]
print(type(num))
# Out:
# <class 'list'>

# %%
num_to_array = np.array(num)

# %%
num_to_a
