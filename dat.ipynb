# %%
Profile={"first_name":"John",
            "last_name":"Jamie",
            "gender":"Male"
}
print(f"""My name is {Profile["first_name"]} and I am {Profile["gender"]}""")
# Out:
# My name is John and I am Male

# %%
num = 0
while num <=19:
    num += 1
    print(f""" 5 X {num} = {num * 5}""")
# Out:
#  5 X 1 = 5
#  5 X 2 = 10
#  5 X 3 = 15
#  5 X 4 = 20
#  5 X 5 = 25
#  5 X 6 = 30
#  5 X 7 = 35
#  5 X 8 = 40
#  5 X 9 = 45
#  5 X 10 = 50
#  5 X 11 = 55
#  5 X 12 = 60
#  5 X 13 = 65
#  5 X 14 = 70
#  5 X 15 = 75
#  5 X 16 = 80
#  5 X 17 = 85
#  5 X 18 = 90
#  5 X 19 = 95
#  5 X 20 = 100

# %%
num = input("Enter a digit to confirm if it is prime, odd or even?")
numint = int(num)
if(numint % 2 == 0):
    print(f"""this is even {numint}""")
print(f"""this is {num}""")
# Out:
# Enter a digit to confirm if it is prime, odd or even? 7
# this is 7

# %%
num = input("Enter a digit to confirm if it is prime, odd or even?")
numint = int(num)
if(numint % 3 == 0):
    print(f"""this is odd {numint}""")
print(f"""this is {num}""")
# Out:
# Enter a digit to confirm if it is prime, odd or even? 9
# this is odd 9
# this is 9

# %%
num = input("Enter a digit to confirm if it is prime, odd or even?")
numint = int(num)
if(numint % 3 == 0):
    print(f"""this is odd {numint}""")
print(f"""this is prime {num}""")
# Out:
# Enter a digit to confirm if it is prime, odd or even? 19
# this is prime 19

# %%
en= "I am a data specialist"
def Person():
    nam = "my name is John "
    age = "I am 22 years old "
    print(nam + "and "  + age + en )
Person()
# Out:
# my name is John and I am 22 years old I am a data specialist
