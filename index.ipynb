# %%
first_name="Femi"

# %%
print(first_name)
# Out:
# Femi

# %%
fname = "John"
age= 30
Sentence= "My name is" + " " + fname  + " " +  str(age)
print(Sentence)
# Out:
# My name is John 30

# %%
fname = "John"
age= 30
Sentence= f"""{My name is fname age"""
print(Sentence)
